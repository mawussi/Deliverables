# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
import seaborn as sns
# %matplotlib inline

# %%
sns.set_context('paper', font_scale=1.7)
sns.set_style('whitegrid')
#mpl.rc('font', **{'family':'serif', 'serif':['Computer Modern Roman'],
#                                'monospace': ['Computer Modern Typewriter']})
params = {'backend': 'pdf',
          #'axes.labelsize': 8,
          'font.size': 10,
          'legend.fontsize': 8,
          #'xtick.labelsize': 8,
          #'ytick.labelsize': 8,
#          'text.usetex': True,
          #'figure.figsize': fig_size,
          'axes.unicode_minus': True,
          'image.cmap': 'plasma'}
plt.rc('font', family='serif', serif='Times')
plt.rc('text', usetex=True)
plt.rc('xtick', labelsize=8)
plt.rc('ytick', labelsize=8)
plt.rc('axes', labelsize=8)
mpl.rcParams.update(params)

# %%
# Setup
routines = ['dgemm', 'dgeqrf', 'dgetrf', 'dpotrf', 'sgemm', 'sgeqrf', 'sgetrf', 'spotrf']

# %%
for routine in routines:
    fig = plt.figure()
    width = 3.487
    height = width/1.618
    LW = 1.5
    
    data = pd.read_csv(routine+'.csv')
    plt.plot(data.n, data.untuned, 'b-', label='untuned', linewidth=LW)
    plt.plot(data.n, data.tuned, 'r-', label='tuned', linewidth=LW)
    
    plt.xlabel(r'$n$')
    plt.ylabel(r'$\mathrm{GFlop/s}$')
    plt.legend(loc='best')
    plt.title(r'$\mathrm{'+routine+r'\_haswell}$', fontsize=12)

    fig.set_size_inches(width, height)
    plt.savefig('../fig/tuned_'+routine+'.eps', bbox_inches='tight')
